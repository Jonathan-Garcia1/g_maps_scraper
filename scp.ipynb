# %%
from webdriver_manager.chrome import ChromeDriverManager

# Specify the ChromeDriver version you want to use
chrome_driver_version = "114.0.5735.90"

# Initialize the ChromeDriverManager with the specified version
driver_manager = ChromeDriverManager(version=chrome_driver_version)

# Get the path to the ChromeDriver executable
chrome_driver_path = driver_manager.install()
# Out:
# ====== WebDriver manager ======
# Driver [/Users/jongarcia/.wdm/drivers/chromedriver/mac64/114.0.5735.90/chromedriver] found in cache

# %%
# !python scraper.py --N 50 --i urls_1.txt --debug
# Out:
# Initializing GoogleMapsScraper...
# Starting __get_driver
# Initializing ChromeDriver...
# ChromeDriver successfully initialized.
# Starting __get_logger
# Initializing logger...
# Logger successfully initialized.
# GoogleMapsScraper initialized successfully.
# Entering GoogleMapsScraper context.
# Scraper initialized successfully.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJIyiwrqX0wokR1x1J2xWMNsg
# Attempting to sort reviews...
# Starting sort_by
# Attempting to navigate to URL...
# URL navigation successful.
# Starting __click_on_cookie_agreement
# Clicking on cookie agreement...
# Failed to click on cookie agreement.
# Failed to click cookie agreement or not found.
# Starting __scroll
# Successfully scrolled
# Starting __expand_reviews
# Successfully expanded reviews.
# Attempting to click sorting button...
# Sorting button clicked successfully.
# Attempting to select sorting option index 1...
# Sorting option selected successfully.
# ...

# %%
# !python scraper.py --N 50 --i urls_1.txt

# %%
from scraper import run_scraper

# Call the function with your desired arguments
run_scraper(N=50, i='urls_1.txt', sort_by='newest', place=False, debug=False, source=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jongarcia/codeup-data-science/googlemaps-scraper/scp.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/googlemaps-scraper/scp.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from scraper import run_scraper
#       <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/googlemaps-scraper/scp.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> # Call the function with your desired arguments
# ----> <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/googlemaps-scraper/scp.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> run_scraper(N=50, i='urls_1.txt', sort_by='newest', place=False, debug=False, source=False)
#
# File ~/codeup-data-science/googlemaps-scraper/scraper.py:85, in run_scraper(N, i, sort_by, place, debug, source)
#      82 def run_scraper(N, i, sort_by, place, debug, source):
# ...
